# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/pinecone-io/examples/blob/master/learn/search/semantic-search/cohere-rerank/compaq-reranking.ipynb)

# %% [markdown]
# # Pinecone & Cohere Rerank
# This notebook downloads and processes Compaq's 10-K SEC filings, using Pinecone vector search and Cohere Rerank 3.5 to extract targeted insights from the documents. The two-stage retrieval combines efficient vector search with semantic reranking for improved results.

# %%
# %pip install --quiet --upgrade \
    pinecone-notebooks \
    python-dotenv \
    pinecone \
    pinecone-plugin-records \
    "rich[jupyter]"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.3/427.3 kB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.4/267.4 kB 17.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 50.5 MB/s eta 0:00:00

# %%
# Standard library imports
import os
import re
import time
import getpass
import difflib
from html import unescape

# Third-party imports
import requests
from tqdm import tqdm
from dotenv import load_dotenv
import pandas as pd
from IPython.display import display, HTML
import ipywidgets as widgets

# Pinecone and Rich libraries
from pinecone import Pinecone
from rich import print as rprint
from rich.console import Console
from rich.table import Table
from rich import box

# %% [markdown]
# # Data Acquisition
# Download Compaq's 10-K filings from the SEC Edgar database.

# %%
# The common base URL for SEC EDGAR filings
BASE_URL = "https://www.sec.gov/Archives/edgar/data/714154/"

# Each year's unique URL tail
URL_TAILS = {
    "1994": "0000714154-94-000005.txt",
    "1995": "0000714154-95-000007.txt",
    "1996": "0000714154-96-000006.txt",
    "1997": "0000950129-97-000786.txt",
    "1998": "0001015402-98-000028.txt",
    "1999": "0001015402-99-000214.txt",
    "2000": "000091205700008116/0000912057-00-008116.txt",
    "2001": "000089056601000112/0000890566-01-000112.txt",
    "2002": "000095012902000383/0000950129-02-000383.txt",
}

# Prompt for company name and email, with the email input hidden
user_company = input("Enter your company name: ")
user_email = getpass.getpass("Enter your email address (input hidden): ")
user_agent_declaration = f"{user_company} {user_email}"

headers = {
    "User-Agent": user_agent_declaration,
    "Accept-Encoding": "gzip, deflate",
    "Host": "www.sec.gov"
}

def download_10ks(url_tails: dict, base_url: str, download_dir: str = "data") -> None:
    """
    Download SEC 10-K filings for each specified year.

    Args:
        url_tails (dict): Mapping of year to file tail URL.
        base_url (str): The base URL for filings.
        download_dir (str): Directory to save downloaded files.
    """
    os.makedirs(download_dir, exist_ok=True)

    for year, tail in tqdm(url_tails.items(), desc="Downloading filings", unit="file"):
        url = f"{base_url}{tail}"
        response = requests.get(url, headers=headers)
        file_path = os.path.join(download_dir, f"{year}.txt")
        with open(file_path, 'w', encoding='utf-8') as file:
            file.write(response.text)
        time.sleep(1)


download_10ks(URL_TAILS, BASE_URL)
# Out:
# Enter your company name: Pinecone
# Enter your email address (input hidden): ··········
# Downloading filings: 100%|██████████| 9/9 [00:10<00:00,  1.15s/file]

# %%
texts = {
    year: open(f"data/{year}.txt", encoding="utf-8").read()
    for year in URL_TAILS.keys()
}

# %% [markdown]
# # Data Preprocessing
# Remove unwanted tags, extract tables, and split the data into manageable chunks.

# %%
def remove_unwanted_tags(text: str, keep_tags: list = None) -> str:
    """
    Remove all HTML/XML tags from text except for specified tags to keep.

    Args:
        text (str): Input text containing tags.
        keep_tags (list, optional): List of tag names to retain (without angle brackets).
                                    Defaults to ["TABLE"].

    Returns:
        str: Cleaned text with unwanted tags removed.
    """
    if keep_tags is None:
        keep_tags = ["TABLE"]
    keep_pattern = '|'.join(keep_tags)
    pattern = re.compile(rf'<(?!/?(?:{keep_pattern})\b)[^>]+>')
    return pattern.sub('', text)


def parse_10ks(year: str, document_text: str) -> str:
    """
    Extract and clean the text enclosed within <TEXT> tags of a 10-K filing.

    Args:
        year (str): The filing year.
        document_text (str): Raw text of the filing.

    Returns:
        str: Cleaned text within the <TEXT> tags, or an empty string if not found.
    """
    pattern = re.compile(r"<TEXT>(.*?)</TEXT>", re.DOTALL)
    matches = pattern.findall(document_text)
    if not matches:
        print(f"Document text not found for year {year}")
        return ""
    return remove_unwanted_tags(matches[0])

# %% [markdown]
# ## Chunking Data by Tables
# This section splits the document text into table sections and non-table text.

# %%
def chunk_by_table(document_text: str) -> dict:
    """
    Split document text into table and non-table parts.

    Args:
        document_text (str): Raw document text.

    Returns:
        dict: Dictionary with keys 'tables' (list of table sections)
              and 'texts' (concatenated non-table text).
    """
    chunks = {"tables": [], "texts": []}
    table_pattern = re.compile(r'(<TABLE.*?</TABLE>)', re.DOTALL | re.IGNORECASE)
    parts = table_pattern.split(document_text)

    for part in parts:
        if not part.strip():
            continue
        if table_pattern.match(part):
            chunks["tables"].append(part)
        else:
            chunks["texts"].append(part)

    chunks["texts"] = "".join(chunks["texts"])
    return chunks

test_table_chunking = chunk_by_table(texts['1996'])

print((test_table_chunking["tables"][0]))
# Out:
# <TABLE> <S> <C>
#
# <ARTICLE> 5
# <LEGEND>
# THIS SCHEDULE CONTAINS SUMMARY FINANCIAL INFORMATION EXTRACTED FROM
# COMPAQ COMPUTER CORPORATION'S CONSOLIDATED BALANCE SHEET AND CONSOLIDATED
# STATEMENT OF INCOME FOR THE PERIOD ENDED DECEMBER 31, 1995 AND IS QUAILIFIED
# IN ITS ENTIRETY BY REFERENCE TO SUCH FINANCIAL STATEMENTS.
# </LEGEND>
# <MULTIPLIER> 1,000,000
#
# <S>                             <C>
# <PERIOD-TYPE>                   YEAR
# <FISCAL-YEAR-END>                          DEC-31-1995
# <PERIOD-END>                               DEC-31-1995
# <CASH>                                             745
# <SECURITIES>                                         0
# <RECEIVABLES>                                    3,241
# <ALLOWANCES>                                       100
# <INVENTORY>                                      2,156
# <CURRENT-ASSETS>                                 6,527
# <PP&E>                                           1,981
# <DEPRECIATION>                                     871
# <TOTAL-ASSETS>                                   7,818
# <CURRENT-LIABILITIES>                            2,680
# <BONDS>                                            300
# <PREFERRED-MANDATORY>                                0
# <PREFERRED>                                          0
# <COMMON>                                           890
# <OTHER-SE>                                       3,724
# <TOTAL-LIABILITY-AND-EQUITY>                     7,818
# <SALES>                                         14,755
# <TOTAL-REVENUES>                                14,755
# <CGS>                                           11,367
# <TOTAL-COSTS>                                   11,367
# <OTHER-EXPENSES>                                   511<F1>
# <LOSS-PROVISION>                                    43
# <INTEREST-EXPENSE>                                  99
# <INCOME-PRETAX>                                  1,188
# <INCOME-TAX>                                       399
# <INCOME-CONTINUING>                                789
# <DISCONTINUED>                                       0
# <EXTRAORDINARY>                                      0
# <CHANGES>                                            0
# <NET-INCOME>                                       789
# <EPS-PRIMARY>                                     2.88
# <EPS-DILUTED>                                     2.87
# <FN>
# <F1>Includes research and development costs and purchased in-process technology.
# </FN>
#
#
#
# </TABLE>

# %%
test_table_chunking = chunk_by_table(texts['1996'])

parse_10ks(1996, test_table_chunking["texts"])
# Out:
# '\n\n______________________________________________________________________\n\n                  SECURITIES AND EXCHANGE COMMISSION\n                        Washington, D.C. 20549\n\n                              FORM 10-K\n\n           ANNUAL REPORT PURSUANT TO SECTION 13 OR 15(d) OF\n                 THE SECURITIES EXCHANGE ACT OF 1934\n\n             For the Fiscal Year Ended December 31, 1995\n\n                    Commission File Number 1-9026\n\n                     COMPAQ COMPUTER CORPORATION\n        (Exact name of registrant as specified in its charter)\n\n             Delaware                        76-0011617\n (State or other jurisdiction of          (I.R.S. Employer\n  incorporation or organization)        Identification No.)\n\n                  20555 SH 249, Houston, Texas 77070\n                            (713) 370-0670\n    (Address, including zip code, and telephone number, including\n       area code, of registrant\'s principal executive offices)\n\nSecurities registered pursuant to Section 12(b) of the Act:\n\n                                                 Name of each exchange on\n            Title of each class                      which registered\n\n       Common Stock, $.01 par value              New York Stock Exchange\n              Debt Securities                              None\n\nSecurities registered pursuant to Section 12(g) of the Act:  None\n\n     Indicate by check mark whether the registrant (1) has filed all\nreports required to be filed by Section 13 or 15(d) of the Securities\nExchange Act of 1934 during the preceding 12 months (or for such\nshorter period that the registrant was required to file such reports),\nand (2) has been subject to such filing requirements for the past 90\ndays.  Yes [ x ]  No [   ]\n\n     Indicate by check mark if disclosure of delinquent filers\npursuant to Item 405 of Regulation S-K is not contained herein, and\nwill not be contained, to the best of registrant\'s knowledge, in\ndefinitive proxy or information statements incorporated by reference\nin Part III of this Form 10-K or any amendment to this Form 10-K. [ x ]\n\n     The aggregate market value of the voting stock held by non-\naffiliates of the registrant on January 31, 1996 (based on the last\nsale price on the New York Stock Exchange as of such date), was $12.5\nbillion.\n\n     The number of shares of the registrant\'s Common Stock, $.01 par\nvalue, outstanding as of January 31, 1996, was 267 million.\n\n                 DOCUMENTS INCORPORATED BY REFERENCE\n\n     There is incorporated by reference in Part III of this Annual\nReport on Form 10-K the information contained in the registrant\'s\nproxy statement for its annual meeting of stockholders to be held\nApril 25, 1996.\n______________________________________________________________________\n\n\nPART I\n\nItem 1.  Business\n\nGeneral\n\n     Compaq Computer Corporation, founded in 1982, designs, develops,\nmanufactures, and markets a wide range of personal computing products,\nincluding desktop personal computers, portable computers, and tower PC\nservers and peripheral products that store and manage data in network\nenvironments.  The Company markets its products primarily to business,\nhome, government, and education customers.  The Company operates in\none principal industry segment across geographically diverse markets.\nAs used herein, the term "Company" means Compaq Computer Corporation\nand its consolidated subsidiaries, unless the context indicates\notherwise.\n\n     In 1995 the Company reinforced its position as the largest\nsupplier of personal computers in the world.  It maintained\napproximately 10% of the expanding worldwide PC market by focusing its\nbusiness activities on expanding sales to new customers while\naugmenting sales to its existing customer base.  Business customers\naccount for the largest portion of the Company\'s sales.  Business\ncustomers are attracted to the Company\'s products for a variety of\nreasons, in ...

# %%
# split into table/not table

split_by_table = {
    year: chunk_by_table(text)
    for year, text in texts.items()
}

# %%
# clean the non-table bits

clean_texts = {
    year: {"tables": chunk_data["tables"],
           "texts": parse_10ks(year, chunk_data["texts"])}
    for year, chunk_data in split_by_table.items()
}

# %% [markdown]
# ## Text Chunking

# %%
CHAR_CHUNKS = 1500

def chunk_text(text: str, chunk_size: int) -> list:
    """
    Split text into chunks of a specified size.

    Args:
        text (str): The text to be split.
        chunk_size (int): Maximum number of characters per chunk.

    Returns:
        list: A list of text chunks.
    """
    return [text[i:i + chunk_size] for i in range(0, len(text), chunk_size)]

# chunk the texts, ignore the tables

chunked_texts = {
    year: {"tables": chunk_data["tables"],
           "texts": chunk_text(chunk_data["texts"], CHAR_CHUNKS)}
    for year, chunk_data in clean_texts.items()
}

# %%
print(chunked_texts['1995']['tables'])
# Out:
# ["<TABLE> <S> <C>\n\n<PAGE>\n<ARTICLE> 5\n<LEGEND>\nTHIS SCHEDULE CONTAINS SUMMARY FINANCIAL INFORMATION EXTRACTED FROM\nCOMPAQ COMPUTER CORPORATION'S CONSOLIDATED BALANCE SHEET AND CONSOLIDATED\nSTATEMENT OF INCOME FOR THE PERIOD ENDED DECEMBER 31, 1994 AND IS QUAILIFIED\nIN ITS ENTIRETY BY REFERENCE TO SUCH FINANCIAL STATEMENTS.\n</LEGEND>\n<MULTIPLIER> 1,000,000\n       \n<S>                             <C>\n<PERIOD-TYPE>                   YEAR\n<FISCAL-YEAR-END>                          DEC-31-1994\n<PERIOD-END>                               DEC-31-1994\n<CASH>                                             471\n<SECURITIES>                                         0\n<RECEIVABLES>                                    2,362\n<ALLOWANCES>                                        75\n<INVENTORY>                                      2,005\n<CURRENT-ASSETS>                                 5,158\n<PP&E>                                           1,672\n<DEPRECIATION>                                     728\n<TOTAL-ASSETS>                                   6,166\n<CURRENT-LIABILITIES>                            2,013\n<BONDS>                                            300\n<COMMON>                                           739\n<PREFERRED-MANDATORY>                                0\n<PREFERRED>                                          0\n<OTHER-SE>                                       2,935\n<TOTAL-LIABILITY-AND-EQUITY>                     6,166\n<SALES>                                         10,866\n<TOTAL-REVENUES>                                10,866\n<CGS>                                            8,139\n<TOTAL-COSTS>                                    8,139\n<OTHER-EXPENSES>                                   226<F1>\n<LOSS-PROVISION>                                    36\n<INTEREST-EXPENSE>                                  71\n<INCOME-PRETAX>                                  1,172\n<INCOME-TAX>                                       305\n<INCOME-CONTINUING>                                867\n<DISCONTINUED>                                       0\n<EXTRAORDINARY>                                      0\n<CHANGES>                                            0\n<NET-INCOME>                                       867\n<EPS-PRIMARY>                                     3.23\n<EPS-DILUTED>                                     3.21\n<FN>\n<F1> Includes research and development costs.\n</FN>\n        \n\n</TABLE>"]

# %% [markdown]
# # Indexing with Pinecone
# ## Setting up Pinecone

# %%
def is_colab():
    try:
        import google.colab
        return True
    except ImportError:
        return False

# Load API key based on environment
if is_colab():
    from google.colab import userdata
    api_key = userdata.get('PINECONE_API_KEY')
else:
    # Local environment - load from .env or environment variable
    load_dotenv()
    api_key = os.environ.get("PINECONE_API_KEY")

if not api_key:
    raise ValueError("PINECONE_API_KEY not found")

pc = Pinecone(api_key=api_key)
index_name = "reranking-compaq"

# %%
# Set up index:
if not pc.has_index(index_name):
    index_model = pc.create_index_for_model(
        name=index_name,
        cloud="aws",
        region="us-east-1",
        embed={
            "model": "multilingual-e5-large",
            "field_map": {"text": "chunk_text"}
        }
    )

# Then get the index reference for operations
index = pc.Index(index_name)

# %% [markdown]
# ## Data Transformation for Indexing

# %%
# Target the created index for upsert and search

index = pc.Index(index_name)

# reformat into records, make the ids for each chunk relate to the documentyear

base_string = "compaq"
# then, we add the document year and the chunk number to the base_string to create unique id

all_text_records = []
all_table_records = []

for year, chunks in chunked_texts.items():
    text_records = [
        {
            "chunk_text": chunk,
            "_id": f"{base_string}_{year}#text{num}",
            "filed_year": int(year),
            "chunk_type": "text"
        }
        for num, chunk in enumerate(chunks["texts"])
    ]
    table_records = [
        {
            "chunk_text": chunk,
            "_id": f"{base_string}_{year}#table{num}",
            "filed_year": int(year),
            "chunk_type": "table"
        }
        for num, chunk in enumerate(chunks["tables"])
    ]
    all_text_records.extend(text_records)
    all_table_records.extend(table_records)

# %% [markdown]
# ## Upserting Data to Pinecone

# %%
# we need to upsert in batches of 96 due to limitations of the integrated inference endpoint

def upsert_in_batches(records, batch_size=96):
    for i in range(0, len(records), batch_size):
        batch = records[i:i+batch_size]
        # Extract the record IDs for this batch
        record_ids = [record["_id"] for record in batch]

        # Fetch existing records from the index for these IDs.
        # (Assumes that the returned dict contains a "vectors" key with the current records.)
        existing = index.fetch(ids=record_ids, namespace=base_string)
        existing_ids = set(existing.get("vectors", {}).keys())

        # Filter out records that already exist.
        records_to_upsert = [record for record in batch if record["_id"] not in existing_ids]

        if records_to_upsert:
            index.upsert_records(namespace=base_string, records=records_to_upsert)
            time.sleep(1)

upsert_in_batches(all_text_records)

# Tables exceed size limits.
# upsert_in_batches(all_table_records)

# %% [markdown]
# # Querying the Index

# %%
ranked_results = index.search_records(
    namespace="compaq",
    query={
        "inputs": {"text": "risks to compaq for dollar hedging"},
        "top_k": 20
    },
    rerank={
        "model": "cohere-rerank-3.5",
        "top_n": 3,
        "rank_fields": ["chunk_text"]
    },
    fields=["chunk_text"]
)

hits = ranked_results["result"]["hits"]

for hit in hits:
    chunk = hit['fields']['chunk_text']
    chunk = unescape(chunk)  # Converts &nbsp; to actual non-breaking spaces
    rprint(chunk)
# Out:
# hese hedging
# activities provide only limited protection against currency exchange risks.
# Factors that could affect the effectiveness of Compaq's hedging programs include
# accuracy of sales forecasts, volatility of the currency markets and availability
# of hedging instruments. All currency contracts that are entered into by Compaq
# are components of hedging programs and are entered into for the sole purpose of
# hedging an existing or anticipated currency exposure, not for speculation.
# Although Compaq maintains these programs to reduce the impact of changes in
# currency exchange rates, Compaq's revenues or costs are adversely affected when
# the U.S. dollar sustains a strengthening position against currencies in which
# Compaq sells products and services or a weakening exchange rate against
# currencies in which Compaq incurs costs.
#
#          Based on Compaq's foreign currency exchange instruments outstanding at
# December 31, 2001, Compaq estimates a maximum potential one-day loss in fair
# value of approximately $36 million. Compaq included all foreign exchange
# contracts in the value-at-risk calculation. The holding period for these
# instruments varies from one day to nine months, with the exception of
# instruments held in connection with leasing operations, which have holding
# periods up to four years.
#
#          Changes in interest rates affect interest income earned on Compaq's
# cash equivalents and short-term investments, interest expense on short-term
# borrowings, and the fair value of Compa
# lly accepted in the United States. For some markets, Compaq has determined
# that ongoing hedging of non-U.S. dollar net monetary assets is not cost effective and instead attempts to minimize
# currency exposure risk through working capital management. There can be
# no assurance that such an approach will be successful, especially if a significant and sudden decline occurs in the
# value of local currencies. Compaq purchases foreign currency option contracts from
# time to time as well as short-term forward exchange contracts to protect against currency exchange risks associated
# with the anticipated revenues of Compaq's international marketing
# subsidiaries, with the exception of Latin America and other subsidiaries that reside in countries in which such
# activity would not be cost effective or local regulations preclude this type of
# activity. These hedging activities provide only limited protection against currency exchange risks. Factors that
# could impact the effectiveness of Compaq's hedging programs include accuracy of sales
# forecasts, volatility of the currency markets and availability of hedging instruments. All currency contracts that
# are entered into by Compaq are components of hedging programs and are entered into
# for the sole purpose of hedging an existing or anticipated currency exposure, not for speculation. Although Compaq
# maintains these programs to reduce the impact of changes in currency exchange rates,
# Compaq's revenues or costs are adversely affected when the U.S. doll
# nimize currency
# exposure risk through working capital management. There can be no assurance that
# such an approach will be successful, especially if a significant and sudden
# decline occurs in the value of local currencies. Compaq purchases foreign
# currency option contracts from time to time as well as short-term forward
# exchange contracts to protect against currency exchange risks associated with
# the anticipated revenues of Compaq's international marketing subsidiaries, with
# the exception of certain subsidiaries that reside in countries in which such
# activity would not be cost effective or local regulations preclude this type of
# activity. These hedging activities provide only limited protection against
# currency exchange risks. Factors that could impact the effectiveness of Compaq's
# hedging programs include accuracy of sales forecasts, volatility of the currency
# markets and availability of hedging instruments. All currency contracts that are
# entered into by Compaq are components of hedging programs and are entered into
# for the sole purpose of hedging an existing or anticipated currency exposure,
# not for speculation. Although Compaq maintains these programs to reduce the
# impact of changes in currency exchange rates, Compaq's revenues or costs are
# adversely affected when the U.S. dollar sustains a strengthening position
# against currencies in which Compaq sells products and services or a weakening
# exchange rate against currencies in which Compaq incurs costs.
#
#       Changes in int

# %%
def query_db(query: str, embed_with_rerank: bool = False, filter: dict = None) -> list:
    """
    Query the Pinecone index with an optional rerank.

    Args:
        query (str): The query string.
        embed_with_rerank (bool, optional): Whether to apply reranking. Defaults to False.
        filter (dict, optional): Filter criteria for the query. Defaults to None.

    Returns:
        list: A list of hit records from the index.
    """
    top_k = 20 if embed_with_rerank else 3
    q = {"inputs": {"text": query}, "top_k": top_k}
    if filter is not None:
        q["filter"] = filter

    if embed_with_rerank:
        ranked_results = index.search_records(
            namespace="compaq",
            query=q,
            rerank={
                "model": "cohere-rerank-3.5",
                "top_n": 3,
                "rank_fields": ["chunk_text"]
            },
            fields=["chunk_text"]
        )
    else:
        ranked_results = index.search_records(
            namespace="compaq",
            query=q,
            fields=["chunk_text"]
        )
    return ranked_results["result"]["hits"]

# %% [markdown]
# ## Formatting query results with Rich
#
# We can use Rich to display the results of our queries in a really clean fashion.

# %%
def query_with_formatting(query: str) -> Table:
    """
    Execute a query and format the results into a Rich Table.

    Args:
        query (str): The query string.

    Returns:
        Table: A Rich Table object with side-by-side results.
    """
    without_hits = query_db(query, embed_with_rerank=False, filter={"chunk_type": "text"})
    with_hits = query_db(query, embed_with_rerank=True, filter={"chunk_type": "text"})

    without_texts = [hit['fields']['chunk_text'] for hit in without_hits]
    with_texts = [hit['fields']['chunk_text'] for hit in with_hits]

    table = Table(title=f"Results with query: {query}", show_lines=True)
    table.add_column("Result #", justify="left", style="black", no_wrap=True, width=75)
    table.add_column("Without Rerank", justify="left", style="black", width=500)
    table.add_column("With Rerank", style="blue", justify="left", width=500)

    for i, (no_rerank, with_rerank_text) in enumerate(zip(without_texts, with_texts), start=1):
        table.add_row(str(i), unescape(no_rerank), unescape(with_rerank_text))

    return table

# %% [markdown]
# ## Simple Query

# %% [markdown]
# This query allows us to pull data bout what Compaq sells, and how it corresponds to sales.
#
# In the returned results, we see the Rerank endpoint returning chunks that are more concerned with changes in the product offerings, but not sales, where as the endpoint without rerank is returning sales numbers. Let's see if we can impact this a bit better.

# %%
QUERY = "Changes in Compaq's product offerings and their impacts on sales"
result = query_with_formatting(QUERY)
console = Console()
console.print(result)
# Out:
#                Results with query: Changes in Compaq's product offerings and their impacts on sales
# ┏━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Result #     ┃ Without Rerank                                  ┃ With Rerank                                    ┃
# ┡━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ 1            │ uld be an adverse impact on                     │ ts, which is related to                        │
# │              │ inventory, cash, and related profitability.     │ component costs, is a critical variable in     │
# │              │ The Company faces product                       │ predicting customer decisions to move          │
# │              │ transitions throughout 1996, particularly in    │ to  the  next  generation of products. Because │
# │              │ its commercial desktop                          │ of the lead times associated with              │
# │              │ and systems divisions.  In each product         │ its  volume  production,  should  Compaq  be   │
# │              │ transition cycle the Company                    │ unable to gauge the rate of product            │
# │              │ confronts the challenge of managing the         │ transitions  accurately,  there  could be an   │
# │              │ inventory of its older                          │ adverse impact on inventory levels,            │
# │              │ products and facilitating the sale of older     │ cash,  and  profitability.  In  addition,  as  │
# │              │ Compaq inventory held by                        │ a result of the Tandem and Digital             │
# │              │ resellers as it increases sales of newer PCs.   │ acquisitions,  Compaq  is  engaged  in  direct │
# │              │ The Company provides                            │ sales  of  computer systems with               │
# │              │ currently for estimated product returns and     │ software  developed  to meet customers'        │
# │              │ price protection that may                       │ specific needs.  The long-term nature of       │
# │              │ occur under programs the Company has with its   │ such  contracts  exposes Compaq to risks       │
# │              │ customers and under                             │ associated with changing customer needs        │
# │              │ floor planning arrangements with third-party    │ and  expectations.                             │
# │              │ finance companies.  The                         │                                                │
# │              │ Company and resellers in the U.S. currently     │      Product  Transitions.  In  each product   │
# │              │ hold substantial amounts                        │ cycle, Compaq confronts the risk of            │
# │              │ of inventory of certain of the Company's        │ delays  in production that could impact sales  │
# │              │ products.  The Company                          │ of newer products while it manages             │
# │              │ expects anticipated selected pricing actions    │ the inventory of older products and            │
# │              │ and aggressive marketing                        │ facilitates the sale of older inventory held   │
# │              │ programs in the first half of 1996 to raise     │ by  resellers.  To  ease product transitions,  │
# │              │ dealer sales of these                           │ Compaq carries out pricing actions             │
# │              │ products, which will facilitate product         │ and marketing programs to increase sales by    │
# │              │ transitions.  The success of                    │ resellers. It provides currently for           │
# │              │ this strategy depends upon a variety of         │ estimated  product  returns  and  price        │
# │              │ competitive and market factors                  │ protection that may occur under reseller       │
# │              │ and is subject to the other risks set forth in  │ programs  and  under  floor  planning          │
# │              │ this report.  Should                            │ arrangements  with  third-party  finance       │
# │              │ the Company be unable to sell its inventory of  │ companies.  Should  Compaq  be unable to sell  │
# │              │ older products at                               │ the inventory of older products at             │
# │              │ anticipated prices or if dealers hold higher    │ anticipated prices, should it not anticipate   │
# │              │ than expected amounts of                        │ pricing actions that are necessary,            │
# │              │ inventory subject to price protection at the    │ or  if  dealers  hold higher than expected     │
# │              │ time of planned price                           │ amounts of inventory subject to price          │
# │              │ reductions, there could be a resulting adverse  │                                                │
# │              │ impact on sales, gross                          │                                                │
# │              │ margins, and profitability.                     │                                                │
# │              │                                                 │                                                │
# │              │ Reengineering Implementation.  The Company      │                                                │
# │              │ continues to expand                             │                                                │
# │              │ manufacturing and                               │                                                │
# ├──────────────┼─────────────────────────────────────────────────┼────────────────────────────────────────────────┤
# │ 2            │ icipants confront                               │ g  environment  throughout  1997.              │
# │              │ aggressive pricing practices, continually       │                                                │
# │              │ changing customer demand patterns, and rapid    │      The  personal  computer  industry  is     │
# │              │ technological developments. The cautionary      │ highly  competitive  and marked by             │
# │              │ statements below discuss important factors that │ frequent  product  introductions,  continual   │
# │              │ could cause actual                              │ improvement  in  product                       │
# │              │ results to differ materially from the projected │ price/performance  characteristics  and  a     │
# │              │ results contained in the forward-looking        │ large  number  of  competitors.                │
# │              │ statements in this report.                      │ Approximately  58%  of  Compaq's  CPU sales in │
# │              │                                                 │ 1997 were derived from products                │
# │              │     Inability to transition to direct sales     │ introduced  in  1997.    These  new products   │
# │              │ could negatively affect financial results.  In  │ have been designed to allow us to              │
# │              │ recent years, the market for                    │ achieve  low  product  costs while maintaining │
# │              │ personal computers has shifted from sales       │ the quality and reliability for                │
# │              │ through resellers toward direct sales to end    │ which  our products have been known, thereby   │
# │              │ users. Compaq sells directly to end users in    │ increasing our ability to compete              │
# │              │ all market sectors, but the largest proportion  │ on  price  and  value.                         │
# │              │ of direct sales are                             │                                                │
# │              │ in large enterprise accounts. Products in       │      The  significant  increase  in  sales  in │
# │              │ Commercial Personal Computing are sold          │ 1997 stemmed primarily from an                 │
# │              │ primarily through third-party resellers while   │ increase  in  the  number  of  units  sold and │
# │              │ products in Consumer are sold principally       │ an increase in sales of options                │
# │              │ through retail outlets. Direct                  │ associated with CPU products. In 1997,         │
# │              │ sales present a more efficient business model   │ Compaq's worldwide unit sales increased        │
# │              │ for personal computer sales, particularly for   │ 43%  while  they  increased  23%  in  1996.    │
# │              │ small and medium businesses and large           │ The 1997 increase included a 35%               │
# │              │ enterprise accounts, where customers require    │ expansion  in  unit  sales  of  commercial     │
# │              │ custom configured                               │ CPU  products,  a 62% increase for             │
# │              │ products with short delivery cycle times.       │ consumer  CPU  products  and  a  65%  increase │
# │              │ Compaq has not kept pace with changes in the    │ for  enterprise  CPU products.                 │
# │              │ industry's sales and distribution model and has │ According to third-party estimates, worldwide  │
# │              │ faced challenges in developing and implementing │ unit sales of personal computers               │
# │              │ processes for                                   │ increased  approximately  15%  to  16%  in     │
# │              │ order entry, production of individualized units │ 1997,  in contrast to a 16% to 18%             │
# │              │ and direct distribution. Compaq has established │ increase  in  1996.    Competition  continues  │
# │              │ a variety of programs designed to achieve these │ to have a significant impact on                │
# │              │ capabilities by simplifying its product set and │ prices  of  our  products,  especially those   │
# │              │ pricing                                         │ aimed at the consumer market, and              │
# │              │ model, re-engineering the cha                   │ additional pricing actions may occur as we     │
# │              │                                                 │ attempt to maintain our competitive            │
# │              │                                                 │ mix of price/performance chara                 │
# ├──────────────┼─────────────────────────────────────────────────┼────────────────────────────────────────────────┤
# │ 3            │      The  following  discussion  should  be     │ n  the  supplier  to  support  Compaq's        │
# │              │ read  in  conjunction  with  the                │ requirements  for periods averaging 90 to 120  │
# │              │ consolidated  financial  statements.  Except    │ days. From time to time Compaq has             │
# │              │ as  specifically  indicated, the                │ experienced  significant  price  increases     │
# │              │ forward-looking  statements  contained  in      │ and  limited availability of certain           │
# │              │ this  discussion  do not take into              │ components  that  are  available from multiple │
# │              │ consideration the impact of Compaq's agreement  │ sources. At times Compaq has been              │
# │              │ to merge with Digital Equipment                 │ constrained  by  parts  availability  in       │
# │              │ Corporation  as  described  in  Item  1,  which │ meeting  product  orders  and  future          │
# │              │ is subject to the approval of                   │ constraints  could  have  an  adverse  effect  │
# │              │ Digital's  shareholders as well as certain      │ on Compaq's operating results. On              │
# │              │ regulatory approvals.  We expect to             │ occasion,  Compaq  acquires  component         │
# │              │ consummate  the  merger  in  the  second        │ inventory  in  anticipation  of  supply        │
# │              │ quarter  of  1998.                              │ constraints.  A  restoration  of component     │
# │              │                                                 │ availability and resulting decline in          │
# │              │                                                 │ component  pricing more quickly than           │
# │              │ RESULTS  OF  OPERATIONS                         │ anticipated could have an adverse effect on    │
# │              │                                                 │ Compaq's  operating  results.                  │
# │              │      The  following  table  presents,  as  a    │                                                │
# │              │ percentage  of  sales,  selected                │ MARKETING  AND  DISTRIBUTION                   │
# │              │ consolidated  financial  data  for each of the  │                                                │
# │              │ three years in the period ended                 │      Compaq's  hardware products are sold to   │
# │              │ December  31.                                   │ large and medium-sized business and            │
# │              │                                                 │ government  customers  primarily  through      │
# │              │                                                 │ dealers,  value-added  resellers  and          │
# │              │                                                 │ systems integrators and to small business and  │
# │              │                                                 │ home customers principally through             │
# │              │ SALES                                           │ dealers  and  consumer  channels. In response  │
# │              │                                                 │ to changing industry practices and             │
# │              │      Sales for 1997 increased approximately     │ customer  preferences,  Compaq  is  continuing │
# │              │ $4.6 billion or 23% over the prior              │ its  expansion  of  distribution               │
# │              │ year  as  compared with an increase of $3.3     │ establishments.  Compaq  also sells hardware   │
# │              │ billion or 20% during 1996.  North              │ products directly through its sales            │
# │              │ American sales, which include Canada, increased │ force  and  to small businesses and home       │
# │              │ 26% during 1997, compared with                  │ customers through Compaq's Internet web        │
# │              │ an  increase  of  29%  during  1996.            │ page  at www.compaq.com as well as through its │
# │              │ International sales, excluding Canada,          │ mail order business that features              │
# │              │ represented 45% of total sales in 1997 as       │          --------------                        │
# │              │ compared with 47% in 1996.  European            │ a  variety  of  personal  computers,  printers │
# │              │ sales  increased  21%  during 1997 compared to  │ and  software  products.                       │
# │              │ an increase of 10% during 1996.                 │                                                │
# │              │ Other international sales increased 15% during  │ COMPAQ                                         │
# │              │ 1997, compared with an increase                 │                                                │
# │              │ of  14%  during  1996.  Other international     │                                                │
# │              │ markets experienced adverse market              │                                                │
# │              │ conditions  in  1997.  In  particular,  the     │                                                │
# │              │ weakness in the Asian and Japanese              │                                                │
# │              │ markets  resulted  in  an  aggressive  pricin   │                                                │
# └──────────────┴─────────────────────────────────────────────────┴────────────────────────────────────────────────┘

# %% [markdown]
# ## Numerical Reasoning Capability
#
# Let's take our query and add a requirement on sales numbers. Normal reranking models (and embedding models) cannot handle this level of granularity, so lets see how the Rerank endpoint performs.

# %%
QUERY = "Changes in Compaq's product offerings and their impacts on sales"
numerical = " and show changes greater than 30% in sales"
result = query_with_formatting(QUERY+numerical)
console = Console()
console.print(result)
# Out:
# Results with query: Changes in Compaq's product offerings and their impacts on sales and show changes greater than
#                                                    30% in sales
# ┏━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Result #     ┃ Without Rerank                                  ┃ With Rerank                                    ┃
# ┡━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ 1            │ icipants confront                               │ g  environment  throughout  1997.              │
# │              │ aggressive pricing practices, continually       │                                                │
# │              │ changing customer demand patterns, and rapid    │      The  personal  computer  industry  is     │
# │              │ technological developments. The cautionary      │ highly  competitive  and marked by             │
# │              │ statements below discuss important factors that │ frequent  product  introductions,  continual   │
# │              │ could cause actual                              │ improvement  in  product                       │
# │              │ results to differ materially from the projected │ price/performance  characteristics  and  a     │
# │              │ results contained in the forward-looking        │ large  number  of  competitors.                │
# │              │ statements in this report.                      │ Approximately  58%  of  Compaq's  CPU sales in │
# │              │                                                 │ 1997 were derived from products                │
# │              │     Inability to transition to direct sales     │ introduced  in  1997.    These  new products   │
# │              │ could negatively affect financial results.  In  │ have been designed to allow us to              │
# │              │ recent years, the market for                    │ achieve  low  product  costs while maintaining │
# │              │ personal computers has shifted from sales       │ the quality and reliability for                │
# │              │ through resellers toward direct sales to end    │ which  our products have been known, thereby   │
# │              │ users. Compaq sells directly to end users in    │ increasing our ability to compete              │
# │              │ all market sectors, but the largest proportion  │ on  price  and  value.                         │
# │              │ of direct sales are                             │                                                │
# │              │ in large enterprise accounts. Products in       │      The  significant  increase  in  sales  in │
# │              │ Commercial Personal Computing are sold          │ 1997 stemmed primarily from an                 │
# │              │ primarily through third-party resellers while   │ increase  in  the  number  of  units  sold and │
# │              │ products in Consumer are sold principally       │ an increase in sales of options                │
# │              │ through retail outlets. Direct                  │ associated with CPU products. In 1997,         │
# │              │ sales present a more efficient business model   │ Compaq's worldwide unit sales increased        │
# │              │ for personal computer sales, particularly for   │ 43%  while  they  increased  23%  in  1996.    │
# │              │ small and medium businesses and large           │ The 1997 increase included a 35%               │
# │              │ enterprise accounts, where customers require    │ expansion  in  unit  sales  of  commercial     │
# │              │ custom configured                               │ CPU  products,  a 62% increase for             │
# │              │ products with short delivery cycle times.       │ consumer  CPU  products  and  a  65%  increase │
# │              │ Compaq has not kept pace with changes in the    │ for  enterprise  CPU products.                 │
# │              │ industry's sales and distribution model and has │ According to third-party estimates, worldwide  │
# │              │ faced challenges in developing and implementing │ unit sales of personal computers               │
# │              │ processes for                                   │ increased  approximately  15%  to  16%  in     │
# │              │ order entry, production of individualized units │ 1997,  in contrast to a 16% to 18%             │
# │              │ and direct distribution. Compaq has established │ increase  in  1996.    Competition  continues  │
# │              │ a variety of programs designed to achieve these │ to have a significant impact on                │
# │              │ capabilities by simplifying its product set and │ prices  of  our  products,  especially those   │
# │              │ pricing                                         │ aimed at the consumer market, and              │
# │              │ model, re-engineering the cha                   │ additional pricing actions may occur as we     │
# │              │                                                 │ attempt to maintain our competitive            │
# │              │                                                 │ mix of price/performance chara                 │
# ├──────────────┼─────────────────────────────────────────────────┼────────────────────────────────────────────────┤
# │ 2            │ uld be an adverse impact on                     │ n  the  supplier  to  support  Compaq's        │
# │              │ inventory, cash, and related profitability.     │ requirements  for periods averaging 90 to 120  │
# │              │ The Company faces product                       │ days. From time to time Compaq has             │
# │              │ transitions throughout 1996, particularly in    │ experienced  significant  price  increases     │
# │              │ its commercial desktop                          │ and  limited availability of certain           │
# │              │ and systems divisions.  In each product         │ components  that  are  available from multiple │
# │              │ transition cycle the Company                    │ sources. At times Compaq has been              │
# │              │ confronts the challenge of managing the         │ constrained  by  parts  availability  in       │
# │              │ inventory of its older                          │ meeting  product  orders  and  future          │
# │              │ products and facilitating the sale of older     │ constraints  could  have  an  adverse  effect  │
# │              │ Compaq inventory held by                        │ on Compaq's operating results. On              │
# │              │ resellers as it increases sales of newer PCs.   │ occasion,  Compaq  acquires  component         │
# │              │ The Company provides                            │ inventory  in  anticipation  of  supply        │
# │              │ currently for estimated product returns and     │ constraints.  A  restoration  of component     │
# │              │ price protection that may                       │ availability and resulting decline in          │
# │              │ occur under programs the Company has with its   │ component  pricing more quickly than           │
# │              │ customers and under                             │ anticipated could have an adverse effect on    │
# │              │ floor planning arrangements with third-party    │ Compaq's  operating  results.                  │
# │              │ finance companies.  The                         │                                                │
# │              │ Company and resellers in the U.S. currently     │ MARKETING  AND  DISTRIBUTION                   │
# │              │ hold substantial amounts                        │                                                │
# │              │ of inventory of certain of the Company's        │      Compaq's  hardware products are sold to   │
# │              │ products.  The Company                          │ large and medium-sized business and            │
# │              │ expects anticipated selected pricing actions    │ government  customers  primarily  through      │
# │              │ and aggressive marketing                        │ dealers,  value-added  resellers  and          │
# │              │ programs in the first half of 1996 to raise     │ systems integrators and to small business and  │
# │              │ dealer sales of these                           │ home customers principally through             │
# │              │ products, which will facilitate product         │ dealers  and  consumer  channels. In response  │
# │              │ transitions.  The success of                    │ to changing industry practices and             │
# │              │ this strategy depends upon a variety of         │ customer  preferences,  Compaq  is  continuing │
# │              │ competitive and market factors                  │ its  expansion  of  distribution               │
# │              │ and is subject to the other risks set forth in  │ establishments.  Compaq  also sells hardware   │
# │              │ this report.  Should                            │ products directly through its sales            │
# │              │ the Company be unable to sell its inventory of  │ force  and  to small businesses and home       │
# │              │ older products at                               │ customers through Compaq's Internet web        │
# │              │ anticipated prices or if dealers hold higher    │ page  at www.compaq.com as well as through its │
# │              │ than expected amounts of                        │ mail order business that features              │
# │              │ inventory subject to price protection at the    │          --------------                        │
# │              │ time of planned price                           │ a  variety  of  personal  computers,  printers │
# │              │ reductions, there could be a resulting adverse  │ and  software  products.                       │
# │              │ impact on sales, gross                          │                                                │
# │              │ margins, and profitability.                     │ COMPAQ                                         │
# │              │                                                 │                                                │
# │              │ Reengineering Implementation.  The Company      │                                                │
# │              │ continues to expand                             │                                                │
# │              │ manufacturing and                               │                                                │
# ├──────────────┼─────────────────────────────────────────────────┼────────────────────────────────────────────────┤
# │ 3            │ e personal computer industry, Compaq            │ ing 35 new                                     │
# │              │ ordinarily acquires materials and components    │ notebook, desktop, and server computer models. │
# │              │ through purchase orders typically               │ Approximately 36% of the                       │
# │              │ covering the Company's requirements for periods │ Company's CPU sales and 30% of the Company's   │
# │              │ averaging 90 to 120 days.  From                 │ sales in 1993 were derived from                │
# │              │ time to time the Company has experienced        │ products introduced in 1993.  These new        │
# │              │ significant price increases and                 │ products have been designed to allow           │
# │              │ limited availability of certain components that │ the Company to achieve low product costs while │
# │              │ are available from multiple                     │ maintaining the quality and                    │
# │              │ sources, such as dynamic random-access memory   │ reliability for which the Company's products   │
# │              │ devices.  In 1993 the Company was               │ have been known, thereby                       │
# │              │ constrained by parts availability in meeting    │ increasing the Company's ability to compete on │
# │              │ product orders.  Any similar                    │ price and value.                               │
# │              │ occurrences in the future could have an adverse │                                                │
# │              │ effect on the Company's                         │                                                │
# │              │ operating results.                              │ PAGE 9                                         │
# │              │                                                 │                                                │
# │              │                                                 │      The Company's significant increase in     │
# │              │ PAGE 3                                          │ consolidated sales in 1993 stemmed             │
# │              │                                                 │ primarily from an increase in the number of    │
# │              │ Marketing and Distribution                      │ units sold.  In 1993 the Company's             │
# │              │                                                 │ worldwide unit shipments increased 98%, while  │
# │              │      The Company distributes its products       │ they increased 78% in 1992.  The               │
# │              │ principally through third-party                 │ 1993 increase included a 196% expansion in     │
# │              │ computer resellers.  In response to changing    │ unit shipments of the Company's                │
# │              │ industry practices and customer                 │ tower server CPU products.  Unit growth        │
# │              │ preferences, the Company is continuing its      │ primarily resulted from the Company's          │
# │              │ expansion into new distribution                 │ aggressively priced Compaq ProLinea line in    │
# │              │ channels, such as mass merchandise stores,      │ its desktop products, the Compaq               │
# │              │ consumer electronics outlets, and               │ Contura portable lines, and the Compaq         │
# │              │ computer superstores.  The Company's products   │ Prosignia products in its tower systems.       │
# │              │ are sold to large and medium-                   │ The Company believes that the personal         │
# │              │ sized business and government customers through │ computer industry as a whole experienced       │
# │              │ dealers, value-added resellers,                 │ significant increases in unit shipments in     │
# │              │ and systems integrators and to small business   │ 1993, especially in North America,             │
# │              │ and home customers through                      │ with industry unit growth worldwide according  │
# │              │ dealers, consumer channels, and beginning in    │ to third party estimates                       │
# │              │ March 1993 directly through the                 │ increasing approximately 20% in contrast to a  │
# │              │ Company's DirectPlus mail order business that   │ 19% increase in 1992.  Industry                │
# │              │ features a variety of personal                  │ unit growth did not translate directly into    │
# │              │ computers, printers, and software products.     │ sales growth because of                        │
# │              │ Business customers account for the              │ significantly lower unit prices.  Third-party  │
# │              │ largest portion of the Company's revenues.      │ estimates indicate that industry               │
# │              │ Business customers are attracted to             │ sales increased by approximately 16% worldw    │
# │              │ the Company's products for                      │                                                │
# └──────────────┴─────────────────────────────────────────────────┴────────────────────────────────────────────────┘

# %% [markdown]
# We can see that the rerank endpoint returns chunks that analyze sales changes in excess of 30%, whereas without reranking we don't get these figures!

# %% [markdown]
# ## Negation Capabilities
#
# The Rerank endpoint is also excellent at taking exclusion requirements for returned queries into account. This is not a typical capability for LLMs, and is often cited as a hinderance for reasoning tasks.
#
# Let's try to expose this reasoning by asking about the acquisitions in Compaq history:

# %%
base_query = "largest acquisitions in compaq history"
result = query_with_formatting(base_query)
console = Console()
console.print(result)
# Out:
#                             Results with query: largest acquisitions in compaq history
# ┏━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Result #     ┃ Without Rerank                                  ┃ With Rerank                                    ┃
# ┡━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ 1            │ ggregate  purchase  price  included             │ 1982, Compaq Computer Corporation ("Compaq")   │
# │              │ approximately  $58  million representing        │ is a leading                                   │
# │              │ purchased  technology  and  other  identifiable │ global provider of enterprise technology and   │
# │              │ intangibles  which  are being                   │ solutions. Compaq designs,                     │
# │              │ amortized  over  a  three  year  period.  Pro   │ develops, manufactures and markets hardware,   │
# │              │ forma  statements of operations                 │ software, solutions and services,              │
# │              │ reflecting  the acquisition of Microcom are not │ including industry-leading enterprise          │
# │              │ shown as they would not differ                  │ computing solutions, fault-tolerant            │
# │              │ materially  from  reported  results.            │ business-critical solutions, communciation     │
# │              │                                                 │ products, and desktop and portable             │
# │              │ During  1995,  Compaq  acquired  two  companies │ personal computers that are sold in more than  │
# │              │ that develop, manufacture, and                  │ 200 countries.                                 │
# │              │ supply fast ethernet hubs, switches and related │                                                │
# │              │ products, and a small software                  │       The following discussion should be read  │
# │              │ company.  The  aggregate  purchase  price  of   │ in conjunction with the                        │
# │              │ $386  million  consisted of the                 │ consolidated financial statements. Certain     │
# │              │ issuance  of  1.2 million shares of Compaq      │ statements contained herein may                │
# │              │ common stock, $359 million in cash,             │ constitute forward-looking statements within   │
# │              │ of  which  $22  million  was paid in 1996, and  │ the meaning of the Private                     │
# │              │ the assumption of certain stock                 │ Securities Litigation Reform Act of 1995.      │
# │              │ options.  The  acquisitions  were  accounted    │ These statements involve a number of           │
# │              │ for  as purchases. The aggregate                │ risks, uncertainties and other factors that    │
# │              │ purchase price included $241 million which      │ could cause actual results to differ           │
# │              │ represented the value of in-process             │ materially, as discussed more fully herein.    │
# │              │ technology  that  had  not  yet  reached        │                                                │
# │              │ technological feasibility and had no            │ RESULTS OF OPERATIONS                          │
# │              │ alternative  future  use.  This  amount  was    │                                                │
# │              │ expensed in Compaq's Consolidated               │       Compaq completed the acquisitions of     │
# │              │ Statement  of  Income  during  1995. In         │ Digital Equipment Corporation                  │
# │              │ addition, the aggregate purchase price          │ ("Digital"), Shopping.Com ("SDC") and Zip2     │
# │              │ included  $126  million  representing purchased │ Corp. ("Zip2") and purchased certain           │
# │              │ technology, other identifiable                  │ assets and liabilities of InaCom Corp.         │
# │              │ intangibles  and goodwill which are being       │ ("Inacom") in June 1998, February 1999,        │
# │              │ amortized over a three to seven year            │ April 1999 and February 2000, respectively.    │
# │              │ period.                                         │ These transactions were accounted              │
# │              │                                                 │ for as purchases. In August 1999, Compaq sold  │
# │              │ NOTE  3.    PROPERTY,  PLANT  AND  EQUIPMENT    │ a majority interest in SDC, Zip2               │
# │              │                                                 │ and the AltaVista Company, a business acquired │
# │              │ Property,  plant  and  equipment  are           │ in the Digital acquisition                     │
# │              │ summarized  below:                              │ (collectively "AltaVista") to CMGI, Inc.       │
# │              │                                                 │ ("CMGI"). Accordingly, Compaq's                │
# │              │                                                 │ consolidated financial statements include the  │
# │              │                                                 │ results of operations from the                 │
# │              │                                                 │ respective dates of                            │
# │              │ Depreciation  expense  totaled  $447 million,   │                                                │
# │              │ $387 million and $326 million in                │                                                │
# │              │ 199                                             │                                                │
# ├──────────────┼─────────────────────────────────────────────────┼────────────────────────────────────────────────┤
# │ 2            │ n. Despite Compaq's intent to complete          │ ts                                             │
# │              │ the planned merger, as part of its ordinary     │ key  to  success  is leveraging Compaq's       │
# │              │ course strategic planning, Compaq               │ marketing skills, engineering talent,          │
# │              │ continues to consider its revenue and cost      │ purchasing power, manufacturing capabilities,  │
# │              │ forecasts, capital resources,                   │ distribution strengths and brand               │
# │              │ business units' growth and contraction and      │ name  to  bring to market high-quality,        │
# │              │ other forward-looking planning as a             │ cost-competitive products in different         │
# │              │ stand-alone entity.                             │ price  ranges  with  features  that  appeal    │
# │              │                                                 │ to  a  wide variety of customers.              │
# │              │          In February 1999, Compaq acquired      │                                                │
# │              │ Shopping.Com ("SDC") for an aggregate           │ PENDING    AND  RECENT  ACQUISITIONS           │
# │              │ purchase price of $257 million. In April 1999,  │                                                │
# │              │ Compaq acquired Zip2 Corp.                      │      On  January  26,  1998, Compaq announced  │
# │              │ ("Zip2") for an aggregate purchase price of     │ the execution of an agreement to               │
# │              │ $341 million. These acquisitions                │ acquire  Digital  Equipment  Corporation       │
# │              │ were accounted for as purchases. The            │ ("Digital").  Under the terms of the           │
# │              │ acquisitions of Zip2 and SDC furthered          │ transaction, shareholders of Digital will      │
# │              │ Compaq's announced strategy to be a global      │ receive $30 in cash and 0.945 shares           │
# │              │ leader in Internet access and                   │ of  Compaq  common  stock  for each share of   │
# │              │ infrastructure through superior technology,     │ Digital common stock. Compaq will              │
# │              │ services and partnerships. With                 │ issue approximately 150 million shares of      │
# │              │ these acquisitions Compaq attempted to leverage │ Compaq common stock and $4.8 billion           │
# │              │ its interest in AltaVista                       │ in  cash.  This transaction will be accounted  │
# │              │ Company to become a leading Internet            │ for as a purchase. It is subject               │
# │              │ destination site for information and            │ to the approval of Digital's shareholders as   │
# │              │ e-commerce.                                     │ well as clearance under antitrust              │
# │              │                                                 │ laws  and  other customary closing conditions, │
# │              │                                                 │ and is expected to be completed                │
# │              │                                                 │ in  the  second  quarter  of  1998.            │
# │              │                                                 │                                                │
# │              │                                        2        │                                                │
# │              │                                                 │      In  August  1997,  Compaq  merged  with   │
# │              │                                                 │ Tandem  Computers  Incorporated                │
# │              │          In August 1999, Compaq sold an 81.5    │ ("Tandem")  in  a  stock-for-stock             │
# │              │ percent equity interest in                      │ transaction  accounted for as a pooling of     │
# │              │ AltaVista Company, SDC and Zip2 (collectively   │ interests.    Tandem  provides  its  customers │
# │              │ "AltaVista") to CMGI, Inc.                      │ with  reliable,  scaleable,                    │
# │              │ ("CMGI") for CMGI stock and other consideration │ fault-tolerant  enterprise  computer  systems  │
# │              │ totaling $1.8 billion in an                     │ and client/server solutions.  In               │
# │              │ effort to accelerate AltaVista's move to a      │ connection  with the merger, Compaq issued     │
# │              │ world-leading portal network.                   │ approximately 126 million shares of            │
# │              │                                                 │ Compaq  common  stock,  based  upon an         │
# │              │          In February 2000, Compaq acquired      │ exchange ratio of 1.05 shares of Compaq        │
# │              │ certain configuration and                       │ co                                             │
# │              │ distribution assets of InaCom Corp. ("Inacom"), │                                                │
# │              │ a provider of information                       │                                                │
# │              │ technology services and products, for           │                                                │
# │              │ approximately $370 million in cash and the      │                                                │
# │              │ assumption of certain relat                     │                                                │
# ├──────────────┼─────────────────────────────────────────────────┼────────────────────────────────────────────────┤
# │ 3            │ nce can be given that actual results will not   │ e platforms with an established global         │
# │              │ deviate from                                    │ service and support team.                      │
# │              │ those  assumptions  in  future  periods.        │                                                │
# │              │                                                 │       In February 1999, Compaq acquired        │
# │              │      Similarly,  the  value  assigned  to       │ Shopping.Com ("SDC") for an aggregate          │
# │              │ purchased  in-process  technology for           │ purchase price of $257 million. This           │
# │              │ Microcom, Inc., which Compaq acquired in May    │ acquisition was accounted for as a             │
# │              │ 1997, was determined by identifying             │ purchase.                                      │
# │              │ research  projects  in  areas  including        │                                                │
# │              │ modems, remote access technologies and          │       In April 1999, Compaq acquired Zip2      │
# │              │ others,  for  which  technological  feasibility │ Corp. ("Zip2") for an aggregate                │
# │              │ had  not  been  established;                    │ purchase price of $341 million. This           │
# │              │ estimating  the  costs  to  develop  the        │ acquisition was accounted for as a             │
# │              │ purchased  in-process  technology into          │ purchase.                                      │
# │              │ commercially  viable products;  estimating  the │                                                │
# │              │ resulting  cash flows from such                 │       In August 1999, Compaq sold an 81.5      │
# │              │ projects,  and discounting  the  net  cash      │ percent equity interest in AltaVista           │
# │              │ flows back to the present value.  The           │ Company (a business acquired in the Digital    │
# │              │ discount  rate  included  a  factor  which      │ acquisition), SDC and Zip2                     │
# │              │ took  into  account  the uncertainty            │ (collectively "AltaVista") to CMGI, Inc.       │
# │              │ surrounding the successful  development  of the │ ("CMGI") for CMGI stock valued at $1.8         │
# │              │ purchased in-process technology.                │ billion.                                       │
# │              │                                                 │                                                │
# │              │                                        15       │       In February 2000, Compaq acquired        │
# │              │                                                 │ certain configuration and distribution         │
# │              │ RESTRUCTURING  AND  ASSET  IMPAIRMENT  CHARGES  │ assets of InaCom Corp. ("Inacom"), a provider  │
# │              │                                                 │ of information technology services             │
# │              │      In  June  1998,  Compaq's  management      │ and products, for approximately $370 million   │
# │              │ approved  restructuring  plans which            │ in cash and the assumption of                  │
# │              │ included  initiatives to integrate operations   │ certain related liabilities. This acquisition  │
# │              │ of Compaq and Digital, consolidate              │ was accounted for as a purchase.               │
# │              │ duplicative  facilities,  improve  service      │ Compaq subsequently established Custom Edge    │
# │              │ delivery and reduce overhead.  Total            │ Incorporated (also known as Compaq             │
# │              │ restructuring  costs  of  approximately $1.7    │ Direct) as a wholly owned subsidiary to        │
# │              │ billion were recorded in the second             │ operate the assets acquired from Inacom.       │
# │              │ quarter  related  to these initiatives, $1.5    │                                                │
# │              │ billion of which related to Digital             │       For further information see Note 3 of    │
# │              │ that  was  recorded  as a component of the      │ the Notes to Consolidated Financial            │
# │              │ preliminary purchase price allocation           │ Statements.                                    │
# │              │ and  $286  million  of  which  related to       │                                                │
# │              │ Compaq that was charged to operations.          │ COMPAQ GLOBAL BUSINESS GROUPS                  │
# │              │                                                 │                                                │
# │              │      The  res                                   │       During 2000, Compaq realigned the        │
# │              │                                                 │ operations of its Enterprise Solutions         │
# │              │                                                 │ and Services segment, which resulted in the    │
# │              │                                                 │ formation of two reportable                    │
# │              │                                                 │ segments: Enterprise Computing and Compaq      │
# │              │                                                 │ Global Services. These two segments            │
# │              │                                                 │ accounted for 50 percent of consolidated       │
# │              │                                                 │ revenue                                        │
# └──────────────┴─────────────────────────────────────────────────┴────────────────────────────────────────────────┘

# %% [markdown]
# In the above chunks, we see that Compaq acquired a lot of firms, the largest being Digital Equipment Corporation. Lets see if we can garner analysis from the 10-ks that excludes this company.

# %%
negation = " that is not Digital Equipment Corporation"
result = query_with_formatting(base_query + negation)
console = Console()
console.print(result)
# Out:
#        Results with query: largest acquisitions in compaq history that is not Digital Equipment Corporation
# ┏━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Result #     ┃ Without Rerank                                  ┃ With Rerank                                    ┃
# ┡━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ 1            │ ts                                              │ e platforms with an established global         │
# │              │ key  to  success  is leveraging Compaq's        │ service and support team.                      │
# │              │ marketing skills, engineering talent,           │                                                │
# │              │ purchasing power, manufacturing capabilities,   │       In February 1999, Compaq acquired        │
# │              │ distribution strengths and brand                │ Shopping.Com ("SDC") for an aggregate          │
# │              │ name  to  bring to market high-quality,         │ purchase price of $257 million. This           │
# │              │ cost-competitive products in different          │ acquisition was accounted for as a             │
# │              │ price  ranges  with  features  that  appeal  to │ purchase.                                      │
# │              │ a  wide variety of customers.                   │                                                │
# │              │                                                 │       In April 1999, Compaq acquired Zip2      │
# │              │ PENDING    AND  RECENT  ACQUISITIONS            │ Corp. ("Zip2") for an aggregate                │
# │              │                                                 │ purchase price of $341 million. This           │
# │              │      On  January  26,  1998, Compaq announced   │ acquisition was accounted for as a             │
# │              │ the execution of an agreement to                │ purchase.                                      │
# │              │ acquire  Digital  Equipment  Corporation        │                                                │
# │              │ ("Digital").  Under the terms of the            │       In August 1999, Compaq sold an 81.5      │
# │              │ transaction, shareholders of Digital will       │ percent equity interest in AltaVista           │
# │              │ receive $30 in cash and 0.945 shares            │ Company (a business acquired in the Digital    │
# │              │ of  Compaq  common  stock  for each share of    │ acquisition), SDC and Zip2                     │
# │              │ Digital common stock. Compaq will               │ (collectively "AltaVista") to CMGI, Inc.       │
# │              │ issue approximately 150 million shares of       │ ("CMGI") for CMGI stock valued at $1.8         │
# │              │ Compaq common stock and $4.8 billion            │ billion.                                       │
# │              │ in  cash.  This transaction will be accounted   │                                                │
# │              │ for as a purchase. It is subject                │       In February 2000, Compaq acquired        │
# │              │ to the approval of Digital's shareholders as    │ certain configuration and distribution         │
# │              │ well as clearance under antitrust               │ assets of InaCom Corp. ("Inacom"), a provider  │
# │              │ laws  and  other customary closing conditions,  │ of information technology services             │
# │              │ and is expected to be completed                 │ and products, for approximately $370 million   │
# │              │ in  the  second  quarter  of  1998.             │ in cash and the assumption of                  │
# │              │                                                 │ certain related liabilities. This acquisition  │
# │              │                                                 │ was accounted for as a purchase.               │
# │              │      In  August  1997,  Compaq  merged  with    │ Compaq subsequently established Custom Edge    │
# │              │ Tandem  Computers  Incorporated                 │ Incorporated (also known as Compaq             │
# │              │ ("Tandem")  in  a  stock-for-stock  transaction │ Direct) as a wholly owned subsidiary to        │
# │              │ accounted for as a pooling of                   │ operate the assets acquired from Inacom.       │
# │              │ interests.    Tandem  provides  its  customers  │                                                │
# │              │ with  reliable,  scaleable,                     │       For further information see Note 3 of    │
# │              │ fault-tolerant  enterprise  computer  systems   │ the Notes to Consolidated Financial            │
# │              │ and client/server solutions.  In                │ Statements.                                    │
# │              │ connection  with the merger, Compaq issued      │                                                │
# │              │ approximately 126 million shares of             │ COMPAQ GLOBAL BUSINESS GROUPS                  │
# │              │ Compaq  common  stock,  based  upon an exchange │                                                │
# │              │ ratio of 1.05 shares of Compaq                  │       During 2000, Compaq realigned the        │
# │              │ co                                              │ operations of its Enterprise Solutions         │
# │              │                                                 │ and Services segment, which resulted in the    │
# │              │                                                 │ formation of two reportable                    │
# │              │                                                 │ segments: Enterprise Computing and Compaq      │
# │              │                                                 │ Global Services. These two segments            │
# │              │                                                 │ accounted for 50 percent of consolidated       │
# │              │                                                 │ revenue                                        │
# ├──────────────┼─────────────────────────────────────────────────┼────────────────────────────────────────────────┤
# │ 2            │ -tolerant business-critical solutions,          │ n. Despite Compaq's intent to complete         │
# │              │ networking and communication products,          │ the planned merger, as part of its ordinary    │
# │              │ commercial desktop and portable products and    │ course strategic planning, Compaq              │
# │              │ consumer PCs for the NonStop™ Internet world.   │ continues to consider its revenue and cost     │
# │              │                                                 │ forecasts, capital resources,                  │
# │              │                                                 │ business units' growth and contraction and     │
# │              │     Compaq                                      │ other forward-looking planning as a            │
# │              │ completed the acquisition of Digital Equipment  │ stand-alone entity.                            │
# │              │ Corporation ("Digital"), Shopping.Com ("SDC")   │                                                │
# │              │ and Zip2 Corp. ("Zip2") in June 1998, February  │          In February 1999, Compaq acquired     │
# │              │ 1999 and                                        │ Shopping.Com ("SDC") for an aggregate          │
# │              │ April 1999, respectively. These acquisitions    │ purchase price of $257 million. In April 1999, │
# │              │ were accounted for as purchases. In August      │ Compaq acquired Zip2 Corp.                     │
# │              │ 1999, Compaq sold a majority interest in        │ ("Zip2") for an aggregate purchase price of    │
# │              │ AltaVista Company (a business acquired in the   │ $341 million. These acquisitions               │
# │              │ Digital                                         │ were accounted for as purchases. The           │
# │              │ acquisition), SDC and Zip2 (collectively        │ acquisitions of Zip2 and SDC furthered         │
# │              │ "AltaVista"), to CMGI, Inc. ("CMGI").           │ Compaq's announced strategy to be a global     │
# │              │ Accordingly, Compaq's consolidated financial    │ leader in Internet access and                  │
# │              │ statements include the results of operations    │ infrastructure through superior technology,    │
# │              │ and the estimated fair                          │ services and partnerships. With                │
# │              │ values of the assets acquired and liabilities   │ these acquisitions Compaq attempted to         │
# │              │ assumed from the respective dates of            │ leverage its interest in AltaVista             │
# │              │ acquisition through divestiture or December 31, │ Company to become a leading Internet           │
# │              │ 1999, as applicable.                            │ destination site for information and           │
# │              │                                                 │ e-commerce.                                    │
# │              │                                                 │                                                │
# │              │     Compaq                                      │                                                │
# │              │ completed the acquisition of Tandem Computers   │                                                │
# │              │ Incorporated ("Tandem") in August 1997. This    │                                                │
# │              │ acquisition was accounted for as a pooling of   │                                        2       │
# │              │ interests, consequently, the                    │                                                │
# │              │ financial information for 1997 has been         │                                                │
# │              │ restated to reflect the merger with Tandem.     │          In August 1999, Compaq sold an 81.5   │
# │              │                                                 │ percent equity interest in                     │
# │              │     Principles of consolidation.  The           │ AltaVista Company, SDC and Zip2 (collectively  │
# │              │ consolidated financial statements include the   │ "AltaVista") to CMGI, Inc.                     │
# │              │ accounts of Compaq and its subsidiaries.        │ ("CMGI") for CMGI stock and other              │
# │              │ All significant intercompany transactions and   │ consideration totaling $1.8 billion in an      │
# │              │ balances have been eliminated.                  │ effort to accelerate AltaVista's move to a     │
# │              │                                                 │ world-leading portal network.                  │
# │              │     Use of estimates.  The preparat             │                                                │
# │              │                                                 │          In February 2000, Compaq acquired     │
# │              │                                                 │ certain configuration and                      │
# │              │                                                 │ distribution assets of InaCom Corp.            │
# │              │                                                 │ ("Inacom"), a provider of information          │
# │              │                                                 │ technology services and products, for          │
# │              │                                                 │ approximately $370 million in cash and the     │
# │              │                                                 │ assumption of certain relat                    │
# ├──────────────┼─────────────────────────────────────────────────┼────────────────────────────────────────────────┤
# │ 3            │ n. Despite Compaq's intent to complete          │ ssets sold and for the expenses associated     │
# │              │ the planned merger, as part of its ordinary     │ with the                                       │
# │              │ course strategic planning, Compaq               │ divestiture, Compaq realized a gain of         │
# │              │ continues to consider its revenue and cost      │ approximately $1.2 billion ($670 million,      │
# │              │ forecasts, capital resources,                   │ net of tax). Compaq accounts for its minority  │
# │              │ business units' growth and contraction and      │ investments in CMGI and AltaVista              │
# │              │ other forward-looking planning as a             │ under the cost method. All CMGI share          │
# │              │ stand-alone entity.                             │ information reflects CMGI's two-for-one        │
# │              │                                                 │ stock split, effective January 2000.           │
# │              │          In February 1999, Compaq acquired      │                                                │
# │              │ Shopping.Com ("SDC") for an aggregate           │       In April 1999, Compaq acquired Zip2 for  │
# │              │ purchase price of $257 million. In April 1999,  │ an aggregate purchase price of                 │
# │              │ Compaq acquired Zip2 Corp.                      │ $341 million consisting of $307 million in     │
# │              │ ("Zip2") for an aggregate purchase price of     │ cash, the issuance of employee stock           │
# │              │ $341 million. These acquisitions                │ options to purchase AltaVista stock with a     │
# │              │ were accounted for as purchases. The            │ fair value of $28 million and other            │
# │              │ acquisitions of Zip2 and SDC furthered          │ acquisition costs. In February 1999, Compaq    │
# │              │ Compaq's announced strategy to be a global      │ acquired SDC for an aggregate                  │
# │              │ leader in Internet access and                   │ purchase price of $257 million consisting of   │
# │              │ infrastructure through superior technology,     │ $219 million in cash, the issuance             │
# │              │ services and partnerships. With                 │ of employee stock options to purchase Compaq   │
# │              │ these acquisitions Compaq attempted to leverage │ stock with a fair value of $32                 │
# │              │ its interest in AltaVista                       │ million and other acquisition costs. These     │
# │              │ Company to become a leading Internet            │ transactions were accounted for as             │
# │              │ destination site for information and            │ purchases.                                     │
# │              │ e-commerce.                                     │                                                │
# │              │                                                 │       In June 1998, Compaq consummated its     │
# │              │                                                 │ acquisition of Digital for an                  │
# │              │                                                 │ aggregate purchase price of $9.1 billion. The  │
# │              │                                                 │ purchase price consisted of                    │
# │              │                                        2        │ approximately $4.5 billion in cash, the        │
# │              │                                                 │ issuance of approximately 141 million          │
# │              │                                                 │ shares of Compaq common stock valued at        │
# │              │          In August 1999, Compaq sold an 81.5    │ approximately $4.3 billion and the             │
# │              │ percent equity interest in                      │ issuance of approximately 25 million options   │
# │              │ AltaVista Company, SDC and Zip2 (collectively   │ to purchase Compaq common stock                │
# │              │ "AltaVista") to CMGI, Inc.                      │ valued at approximately $249 million. This     │
# │              │ ("CMGI") for CMGI stock and other consideration │ acquisition was accounted for as a             │
# │              │ totaling $1.8 billion in an                     │ purchase. The unaudited consolidated pro forma │
# │              │ effort to accelerate AltaVista's move to a      │ information for 1998 as if Compaq              │
# │              │ world-leading portal network.                   │ and Digital had been combined as of the        │
# │              │                                                 │ beginning of 1998 included revenue and         │
# │              │          In February 2000, Compaq acquired      │                                                │
# │              │ certain configuration and                       │                                                │
# │              │ distribution assets of InaCom Corp. ("Inacom"), │                                                │
# │              │ a provider of information                       │                                                │
# │              │ technology services and products, for           │                                                │
# │              │ approximately $370 million in cash and the      │                                                │
# │              │ assumption of certain relat                     │                                                │
# └──────────────┴─────────────────────────────────────────────────┴────────────────────────────────────────────────┘

# %% [markdown]
# Interestingly , the returned chunks exclude the purchase of Digital in 1998 when using the reranker, whereas without the reranker we maintain references to Digital Equipment Corporation.
#
# Although this may depend generally on chunking strategy, and the content of text being written about, we can still cleanly demonstrate this behavior without knowing exactly what chunks contain which information.

# %% [markdown]
# ## Temporal Reasoning
#
# The Rerank endpoint is great at using times, dates, and other forms of temporal information in refining results.
#
# Here, we specify products sold in 1999, despite not explicitly filtering on 1999 10-Ks in metadata!

# %%
QUERY = "Consumer products that compaq started selling in 1999 and beyond"
result = query_with_formatting(QUERY)
console = Console()
console.print(result)
# Out:
#                Results with query: Consumer products that compaq started selling in 1999 and beyond
# ┏━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Result #     ┃ Without Rerank                                  ┃ With Rerank                                    ┃
# ┡━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ 1            │ ces  (DSS)  and  E-commerce  solutions.    We   │ orage                                          │
# │              │ will build on our                               │ solutions through the development and delivery │
# │              │ leadership  position  in  storage by offering   │ of StorageWorks(TM) by Compaq                  │
# │              │ our customers new Fibre Channel,                │ storage area networks, automated backup        │
# │              │ DLT  library  and  Enterprise  storage          │ solutions, network attached storage and        │
# │              │ solutions that will allow them to build         │ a complete suite of SANworks(TM) by Compaq     │
# │              │ highly  available,  scalable  storage networks. │ storage management solutions. Network          │
# │              │ In workstations, we expect to                   │ attached storage means storage devices         │
# │              │ expand  our  segment  solutions as well as      │ connected to a network of computers that       │
# │              │ introduce new products offering the             │ store and deliver information to computers in  │
# │              │ latest  graphic  and  high-performance          │ the network. Enterprise Computing              │
# │              │ computing  technologies.                        │ accounted for approximately 32 percent, 34     │
# │              │                                                 │ percent and 34 percent of Compaq's             │
# │              │      Consumer  Products  Group.    In 1997, the │ consolidated revenue in 2001, 2000 and 1999,   │
# │              │ Consumer Products Group, which                  │ respectively.                                  │
# │              │ markets  computers  and  related options aimed  │                                                │
# │              │ at the consumer and home office                 │ ACCESS. The Access segment delivers products   │
# │              │ market,  accounted  for 16% of Compaq's sales.  │ and solutions designed to provide              │
# │              │ In 1997, Compaq introduced its                  │ home and business users with anytime, anywhere │
# │              │ spring  lineup  of home multimedia PCs that     │ access to information,                         │
# │              │ included the Presario 2000 series,              │ communication and entertainment. For the       │
# │              │ the  first series of products in the market to  │ business customer, the Access segment          │
# │              │ combine leading-edge technology                 │ offers a broad range of innovative commercial  │
# │              │ at  prices  below  $1000.   In June, Compaq     │ computing devices, services and                │
# │              │ expanded its consumer line in many              │ solutions. These include desktop, notebook,    │
# │              │ significant  ways,  incorporating  the  latest  │ workstation and thin client products           │
# │              │ processor technologies with new                 │ marketed under the Evo(TM), DeskPro(TM),       │
# │              │ low-cost  form  factors,  easy  internet        │ Armada(TM) and other brands, as well as        │
# │              │ access  capabilities,  DVD-ROM                  │ a full line of Compaq branded monitor and      │
# │              │ capabilities,  and a creativity imaging center  │ networking products - all designed to          │
# │              │ that supports video and digital                 │ help customers simplify their business         │
# │              │ image  capture,  editing  and communications.   │ computing environments. For the consumer       │
# │              │ Compaq also expanded its line of                │ customer, the Access segment offers a wide     │
# │              │ home  notebook  PCs with the latest processor   │ range of innovative products and               │
# │              │ and screen technologies enhanced                │ technologies that all work together to help    │
# │              │ with  multimedia  applications  and             │ the home or home office user                   │
# │              │ consumer-oriented  CD  playback features,       │ simplify their life, connect their world and   │
# │              │ marketed  as  DisqPlay.   The combination of    │ have fun. These include                        │
# │              │ innovative portables and low cost               │ Presario(TM) branded desktop and notebook      │
# │              │ high  technology  desktop  produ                │ Internet PCs and a line of monitors            │
# │              │                                                 │ and printers sold under the Compaq             │
# ├──────────────┼─────────────────────────────────────────────────┼────────────────────────────────────────────────┤
# │ 2            │ fited from high unit growth driven by strong    │ stom                                           │
# │              │ consumer demand, partially                      │ configuration capabilities and direct          │
# │              │ offset by a decline in average unit prices.     │ fulfillment logistics that enable Compaq       │
# │              │ Component costs continued to                    │ to better meet customer needs in North         │
# │              │ decline, which allowed Compaq to reach lower    │ America. Higher unit sales of 27 percent       │
# │              │ price points, thus spurring                     │ in home and office desktops and notebooks also │
# │              │ consumer demand. An increase in international   │ contributed to revenue growth in               │
# │              │ sales also drove total revenue                  │ 2000 compared with 1999 although consumer      │
# │              │ higher, particularly in Latin America and       │ sales late in 2000 were hampered by            │
# │              │ Asia-Pacific. Higher revenue from               │ the lack of a seasonal uplift in sales.        │
# │              │ Internet access and traffic benefited the       │ Revenues benefited from strong                 │
# │              │ Consumer segment in 1999.                       │ international sales growth, particularly in    │
# │              │                                                 │ Asia-Pacific and Latin America.                │
# │              │       Consumer operating income declined $92    │ Access revenue represented 45 percent, 49      │
# │              │ million, or 35 percent, in 2000                 │ percent and 47 percent of consolidated         │
# │              │ compared with the prior year. The decline in    │ revenue in 2001, 2000 and 1999, respectively.  │
# │              │ operating income was primarily due              │                                                │
# │              │ to a downturn in the U.S. consumer PC market    │                                                │
# │              │ that occurred late in the fourth                │                                                │
# │              │ quarter of 2000. Higher component costs also    │                                                │
# │              │ contributed to lower operating                  │                                        21      │
# │              │ income. Operating expenses were relatively      │                                                │
# │              │ unchanged as a percentage of revenue.           │                                                │
# │              │ Consumer operating income increased $79         │          The Access segment incurred an        │
# │              │ million, or 43 percent, in 1999 compared        │ operating loss of $587 million during          │
# │              │ with 1998. The increase in operating income was │ 2001 compared with operating income of $145    │
# │              │ attributable to higher revenue,                 │ million in 2000 as lower gross                 │
# │              │ which resulted in higher gross margin in        │ margins more than offset improvements in       │
# │              │ absolute dollars, and slightly lower            │ operating expense and cost structure.          │
# │              │ operating expenses as a percentage of revenue.  │ Segment gross margins declined 3 percentage    │
# │              │                                                 │ points compared with 2000 due to               │
# │              │                                        15       │ aggressive pricing and weak economic           │
# │              │                                                 │ conditions. Compaq was able to partially       │
# │              │ CORPORATE AND UNALLOCATED SHARED EXPENSES       │ mitigate the downward pressure on margins by   │
# │              │                                                 │ increasing its direct sales mix 12             │
# │              │       The results of the business segments      │ percentage points in North America and         │
# │              │ exclude separately managed corporate            │ introducing a simplified new product line      │
# │              │ and unallocated shared expenses, which          │ centered around the Evo family of personal     │
# │              │ consisted primarily of general and              │ computing products targeted at                 │
# │              │ administrative costs as well as other items not │ corporate customers. The new Evo product       │
# │              │ controlled by the business                      │ family uses simplified form factors and        │
# │              │ segments. Corporate and unallocated shared      │ common components to lower overall unit cost.  │
# │              │ expenses declined from                          │ Operating expense in 2001                      │
# │              │                                                 │ decreased $298 million, or 14 percent,         │
# │              │                                                 │ primarily due to cost reductions               │
# │              │                                                 │ following                                      │
# ├──────────────┼─────────────────────────────────────────────────┼────────────────────────────────────────────────┤
# │ 3            │ q Computer Corporation, together with           │ nd is the leading integrator of Microsoft      │
# │              │ its consolidated subsidiaries, (collectively    │ Exchange, with more than 400 major             │
# │              │ "Compaq") designs, develops,                    │ accounts worldwide. Compaq also has been       │
# │              │ manufactures and markets information technology │ designated as a preferred service provider by  │
# │              │ equipment, software, services                   │ Computer Associates International, Inc.        │
# │              │ and solutions, including industry-leading       │                                                │
# │              │ enterprise storage and computing                │                                                │
# │              │ solutions, fault-tolerant business-critical     │     Compaq                                     │
# │              │ solutions, communication products,              │ provides warranty support to its customers     │
# │              │ personal desktop and notebook computers, and    │ through its own service organization, as well  │
# │              │ personal entertainment and Internet             │ as through full-service resellers and          │
# │              │ access devices that are sold in more than 200   │ independent service companies. In addition to  │
# │              │ countries.                                      │ the                                            │
# │              │                                                 │ support associated with product warranties,    │
# │              │          Compaq completed the acquisition of    │ Compaq offers a broad range of support         │
# │              │ Shopping.Com ("SDC") and Zip2 Corp.             │ services designed to maximize system uptime    │
# │              │ ("Zip2") and purchased certain assets and       │ and optimize system performance.               │
# │              │ liabilities of InaCom Corp. ("Inacom")          │                                                │
# │              │ in February 1999, April 1999 and February 2000, │     Commercial Personal Computing ("CPC").     │
# │              │ respectively. These acquisitions                │ CPC designs, develops, manufactures and        │
# │              │ were accounted for as purchases. In August      │ markets a broad                                │
# │              │ 1999, Compaq sold an 81.5 percent               │ line of standards-based computing products     │
# │              │ equity interest in AltaVista Company to CMGI,   │ emphasizing Internet access through            │
# │              │ Inc. ("CMGI"). Accordingly,                     │ workstations, desktops, portables, monitors,   │
# │              │ Compaq's consolidated financial statements      │ Internet access devices and life-cycle         │
# │              │ include the results of operations               │ management products. CPC                       │
# │              │ from the respective dates of acquisition        │ markets products                               │
# │              │ through divestiture or December 31,             │                                                │
# │              │ 2001, as applicable.                            │ under such brands as Deskpro™ desktops and     │
# │              │                                                 │ Armada™ portables for commercial businesses,   │
# │              │ PRINCIPLES OF CONSOLIDATION. The consolidated   │ Prosignia desktops and portables for small and │
# │              │ financial statements include the                │ growing businesses, Deskpro and                │
# │              │ accounts of Compaq and its controlled           │ Professional workstations, Aero™ handhelds,    │
# │              │ subsidiaries. All significant intercompany      │ and Compaq iPAQ Internet devices. CPC          │
# │              │ transactions and balances have been eliminated. │ accounted for approximately 32 percent of      │
# │              │                                                 │ Compaq's consolidated revenue in 1999.         │
# │              │ CRITICAL ACCOUNTING POLICIES AND ESTIMATES. The │                                                │
# │              │ preparation of consolidated                     │     As                                         │
# │              │ financial statements requires Compaq to make    │ an element of Compaq's strategy to re-define   │
# │              │ estimates and judgments that affect             │ Internet access with innovative products and   │
# │              │ the reported amounts of assets, liabilities,    │ services, CPC introduced the iPAQ legacy-free  │
# │              │ revenues and expenses, and related              │ Internet device in                             │
# │              │ d                                               │ late 1999. The uniquely designed iPAQ is       │
# │              │                                                 │ targeted f                                     │
# └──────────────┴─────────────────────────────────────────────────┴────────────────────────────────────────────────┘
